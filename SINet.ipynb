# %%
import os
import sys
import warnings
# !pip install matplotlib==3.5
warnings.filterwarnings("ignore")

import numpy as np
from keras.layers import (
    Conv2D, BatchNormalization, Dense,
    ZeroPadding2D, Activation, GlobalAveragePooling2D,
    Reshape, Permute, multiply, AveragePooling2D,
    UpSampling2D, Concatenate, Add, Lambda, Multiply
)
from keras.models import Model, Sequential
from keras.layers import Input
import keras.backend as K
from keras.layers import DepthwiseConv2D, PReLU

# %%
import cv2
import imutils
from glob import glob
import pandas as pd
from sklearn.utils import shuffle
import imgaug as ia
from imgaug import augmenters as iaa
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, BaseLogger
from imgaug.augmentables.segmaps import SegmentationMapsOnImage
from keras import __version__
print(__version__)
import tensorflow as tf
tf.__version__
tf.config.list_logical_devices()
# Out:
# 2.14.0
# [LogicalDevice(name='/device:CPU:0', device_type='CPU')]

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4713979435645323906
# xla_global_id: -1
# ]

# %% [markdown]
# ## Constant variable

# %%
IMG_HEIGHT = 224
IMG_WIDTH = 224
IMG_CHANNEL = 3
CLASSES = ["Background", "Person"]
N_CLASSES = 2
IMAGE_DATA_FORMAT = K.image_data_format()

# %% [markdown]
# ## Building Model

# %%
from keras.regularizers import l2
from keras.utils import plot_model

# %%
class SiNet:
    def __init__(self, img_height, img_width, img_channel, n_classes, reg=1e-4):
        self.img_height = img_height
        self.img_width = img_width
        self.img_channel = img_channel
        self.n_classes = n_classes
        self.reg = reg
        self.channel_axis = 1 if K.image_data_format() == "channels_first" else -1
        self.alpha = 1.0
        self.image_val = 0.017
        self.mean_substraction = [103.94, 116.78, 123.68]

    def relu6(self, x):
        return K.relu(x, max_value=6)

    def _conv_block(self, inputs, filters, alpha, strides=(1,1), kernel=(3,3), block_id=1, padding="valid"):
        """"""
        filters = int(filters * alpha)

        if padding=="same":
            x = inputs
        else:
            x = ZeroPadding2D((1, 1), data_format=IMAGE_DATA_FORMAT,
                              name="conv_%s_pad" % block_id)(inputs)

        x = Conv2D(filters, kernel, data_format=IMAGE_DATA_FORMAT,
                   padding=padding, use_bias=False, strides=strides,
                   kernel_initializer="he_normal", kernel_regularizer=l2(self.reg),
                   name="conv_%s" % block_id)(x)
        x = BatchNormalization(axis=self.channel_axis, name="conv_%s_bn" % block_id)(x)
        x = Activation("relu", name="conv_%s_act" % block_id)(x)

        return x

    def _pointwise_conv_block(self, inputs, pointwise_conv_filters, alpha,
                              strides=(1, 1), block_id=1):
        x = Conv2D(pointwise_conv_filters,
                   (1, 1),
                   data_format=IMAGE_DATA_FORMAT,
                   padding="same",
                   use_bias=False,
                   strides=(1, 1),
                   kernel_initializer="he_normal",
                   kernel_regularizer=l2(self.reg),
                   name="conv_pw_%s" % block_id)(inputs)
        x = BatchNormalization(axis=self.channel_axis,
                               name="conv_pw_%s_bn" % block_id)(x)
        x = Activation("relu", name="conv_pw_%s_relu" % block_id)(x)

        return x

    def _depthwise_conv_block(self, inputs, pointwise_conv_filters, alpha,
                              depth_multiplier=1, strides=(1, 1), block_id=1,
                              kernel=(3,3), padding_size=(1, 1)):
        """"""
        pointwise_conv_filters = int(pointwise_conv_filters * alpha)

        x = ZeroPadding2D(padding_size,
                          data_format=IMAGE_DATA_FORMAT,
                          name="conv_pad_%s" % block_id)(inputs)
        x = DepthwiseConv2D(kernel_size=kernel,
                            data_format=IMAGE_DATA_FORMAT,
                            depth_multiplier=depth_multiplier,
                            strides=strides,
                            use_bias=False,
                            depthwise_regularizer=l2(self.reg),
                            name="conv_dw_%s" % block_id)(x)
        x = BatchNormalization(axis=self.channel_axis,
                               name="conv_dw_%s_bn" % block_id)(x)
#         x = Activation("PReLu", name="conv_dw_%d_Prelu" % block_id)(x)
        x = PReLU(name="conv_dw_%s_Prelu" % block_id)(x)

        x = self._pointwise_conv_block(x, pointwise_conv_filters, self.alpha, block_id=block_id)

        return x

    def _squeeze_excite_block(self, inputs, ratio=16, block_id=1):
        """"""
        filters = inputs.shape[self.channel_axis]
        se_shape = (1, 1, filters) if self.channel_axis == -1 else (filters, 1, 1)

        se = GlobalAveragePooling2D(name="squeeze_glo_avg_%s" % block_id)(inputs)
        se = Dense(filters // ratio, activation="relu",
                   kernel_initializer="he_normal",
                   kernel_regularizer=l2(self.reg),
                   use_bias=False, name="squeeze_squ_%s" % block_id)(se)
        se = Dense(filters, activation="relu",
                   kernel_initializer="he_normal",
                   kernel_regularizer=l2(self.reg),
                   use_bias=False,
                   name="squeeze_exci_%s" % block_id)(se)
        se = multiply([inputs, se], name="squeeze_scale_%s" % block_id)

        return se

    def _depthwise_conv_se_block(self, inputs, pointwise_conv_filters, alpha,
                                 depth_multiplier=1, strides=(2, 2), block_id=1,
                                 kernel=(3,3), ratio=16):
        """
        DS-Conv + SE
        """
        x = self._depthwise_conv_block(inputs, pointwise_conv_filters, alpha,
                                       block_id=block_id, strides=strides)
#         x = Activation("relu")(x)
        x = self._squeeze_excite_block(x, ratio=ratio, block_id=block_id)
        x = Activation("relu")(x)

        return x

    def _s2_block(self, inputs, pointwise_conv_filters, alpha,
                  depth_multiplier=1, strides=(1, 1), block_id=1,
                  kernel=(3,3), pool_size=(1,1), padding_size=(1, 1)):
        x = AveragePooling2D(pool_size=pool_size, strides=(2, 2),
                             data_format=IMAGE_DATA_FORMAT, padding="same")(inputs)
        x = Activation("relu")(x)
        x = self._depthwise_conv_block(x, pointwise_conv_filters, alpha,
                                       block_id=block_id, kernel=kernel,
                                       padding_size=padding_size)
        x = UpSampling2D(size=(2, 2), interpolation="bilinear", name="s2_block_%s" % block_id)(x)
        x = BatchNormalization(axis=self.channel_axis)(x)
        x = Activation("relu")(x)

        return x

    def _s2_module(self, inputs, pointwise_conv_filters, alpha,
                   depth_multiplier=1, strides=(1, 1), block_id=1,
                   kernel_conv=(3, 3), kernel_ds_1=(3, 3),
                   kernel_ds_2=(3, 3), pad_ds_1=(1, 1), pad_ds_2=(1, 1),
                   pool_block_1=(1, 1), pool_block_2=(1, 1)):
        """
        The function to build S2 block
        """
        x = self._conv_block(inputs, pointwise_conv_filters, alpha,
                             kernel=(1, 1), block_id=block_id, padding="same")
        x1 = self._s2_block(x, pointwise_conv_filters, alpha, depth_multiplier=depth_multiplier,
                            strides=strides, kernel=kernel_ds_1, block_id=str(block_id) + "_1",
                            padding_size=pad_ds_1, pool_size=pool_block_1)

        x2 = self._s2_block(x, pointwise_conv_filters, alpha, depth_multiplier=depth_multiplier,
                            strides=strides, kernel=kernel_ds_2, block_id=str(block_id) + "_2",
                            padding_size=pad_ds_2, pool_size=pool_block_2)

        x = Concatenate(axis=self.channel_axis)([x1, x2])
        x = Add()([inputs, x])
#         x = BatchNormalization(axis=self.channel_axis)(x)
        x = PReLU()(x)

        return x

    def build_encoder(self):
        """
        Build encoder function
        """

        input_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_CHANNEL)

        if IMAGE_DATA_FORMAT == "channels_first":
            input_shape = (IMG_CHANNEL, IMG_HEIGHT, IMG_WIDTH)

        inputs = Input(shape=input_shape)

        x = Lambda(lambda z: z[...,::-1], output_shape=input_shape,
                   name="swap_color_channel")(inputs)

        if self.mean_substraction:
            x = Lambda(lambda z: (z - np.array(self.mean_substraction))*self.image_val,
                       output_shape=input_shape,
                       name="mean_substraction_inputs")(x)
#         x = inputs

        x1 = self._conv_block(x, 12, self.alpha, strides=(2, 2), block_id=1)
        x2 = self._depthwise_conv_se_block(x1, 16, self.alpha, block_id=2)
        x3 = self._depthwise_conv_se_block(x2, 48, self.alpha, block_id=3, strides=(1, 1))
        x4 = self._s2_module(x3, 24, self.alpha, block_id=4, kernel_ds_2=(5, 5), pad_ds_2=(2, 2))
        x5 = self._s2_module(x4, 24, self.alpha, block_id=5)

        x6 = Concatenate(axis=self.channel_axis, name="concat_2_5")([x2, x5])

        x7 = self._depthwise_conv_se_block(x6, 48, self.alpha, block_id=6)
        x8 = self._depthwise_conv_se_block(x7, 96, self.alpha, block_id=7, strides=(1, 1))
        x9 = self._s2_module(x8, 48, self.alpha, block_id=8, kernel_ds_2=(5, 5), pad_ds_2=(2, 2))
        x10 = self._s2_module(x9, 48, self.alpha, block_id=9)
        x11 = self._s2_module(x10, 48, self.alpha, block_id=10,
                              kernel_ds_1=(5, 5), pad_ds_1=(2, 2),
                              kernel_ds_2=(3, 3), pool_block_2=(2, 2))
        x12 = self._s2_module(x11, 48, self.alpha, block_id=11,
                              kernel_ds_1=(5, 5), pad_ds_1=(2, 2),
                              kernel_ds_2=(3, 3), pool_block_2=(4, 4))
        x13 = self._s2_module(x12, 48, self.alpha, block_id=12)
        x14 = self._s2_module(x13, 48, self.alpha, block_id=13,
                              kernel_ds_1=(5, 5), pad_ds_1=(2, 2),
                              kernel_ds_2=(5, 5), pad_ds_2=(2, 2))
        x15 = self._s2_module(x14, 48, self.alpha, block_id=14,
                              kernel_ds_1=(3, 3), pool_block_1=(2, 2),
                              kernel_ds_2=(3, 3), pool_block_2=(4, 4))
        x16 = self._s2_module(x15, 48, self.alpha, block_id=15,
                              kernel_ds_1=(3, 3), pool_block_1=(1, 1),
                              kernel_ds_2=(5, 5), pad_ds_2=(2, 2), pool_block_2=(2, 2))

        x17 = Concatenate(axis=self.channel_axis, name="concat_16_7")([x16, x7])
        x17 = Activation("relu")(x17)

        x = self._pointwise_conv_block(x17, N_CLASSES, self.alpha, block_id=16)
#         x8_pws = self._pointwise_conv_block(x8, N_CLASSES, self.alpha, block_id=17)
#         x = Add(name="x8_xlast_adding")([x8_pws, x])
        x = Activation("relu")(x)
#         x = Activation("relu")(x)

#         x = Reshape((-1, self.n_classes))(x)

#         x = Activation("softmax")(x)

#         model = Model(inputs=inputs, outputs=x)

        return inputs, x, x8, x5, x1

    def build_decoder(self):
        inputs, x, x8, x5, x1 = self.build_encoder()

        x = UpSampling2D((2, 2), data_format=IMAGE_DATA_FORMAT,
                         interpolation="bilinear")(x)
        x = BatchNormalization(axis=self.channel_axis)(x)
        x_ac = Activation("softmax")(x)

        x_blocking = K.max(x_ac, axis=-1, keepdims=True)

        x_blocking = Lambda(lambda x: 1 - x, name="information_blocking_decoder")(x_blocking)

        x5_pws = self._pointwise_conv_block(x5, self.n_classes, self.alpha, block_id=18)

        x_mul = Multiply()([x5_pws, x_blocking])
        x = Activation("relu")(x)
        x = Add()([x_mul, x])
        x = Activation("relu")(x)
        x = UpSampling2D((2, 2), interpolation="bilinear")(x)
        x = BatchNormalization(axis=self.channel_axis)(x)
        x = Activation("relu")(x)
        x = self._conv_block(x, self.n_classes, self.alpha, kernel=(1, 1), padding="same", block_id=19)
#         x1_pws = self._pointwise_conv_block(x1, self.n_classes, self.alpha, block_id=20, strides=(1, 1))
#         x = Add()([x1_pws, x])
#         x = Activation("relu")(x)
        x = UpSampling2D((2, 2), interpolation="bilinear")(x)
        x = BatchNormalization(axis=self.channel_axis)(x)
        x = Activation("relu")(x)
        x = Reshape((-1, self.n_classes))(x)
        x = Activation("softmax")(x)

        model = Model(inputs=inputs, outputs=x)

        return model

# %%
K.clear_session()
sinet = SiNet(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNEL, N_CLASSES)

# %%
model = sinet.build_decoder()

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  swap_color_channel (Lambda  (None, 224, 224, 3)          0         ['input_1[0][0]']
#  )
#
#  mean_substraction_inputs (  (None, 224, 224, 3)          0         ['swap_color_channel[0][0]']
#  Lambda)
#
#  conv_1_pad (ZeroPadding2D)  (None, 226, 226, 3)          0         ['mean_substraction_inputs[0][
#                                                                     0]']
#
#  conv_1 (Conv2D)             (None, 112, 112, 12)         324       ['conv_1_pad[0][0]']
#
#  conv_1_bn (BatchNormalizat  (None, 112, 112, 12)         48        ['conv_1[0][0]']
#  ion)
#
#  conv_1_act (Activation)     (None, 112, 112, 12)         0         ['conv_1_bn[0][0]']
#
#  conv_pad_2 (ZeroPadding2D)  (None, 114, 114, 12)         0         ['conv_1_act[0][0]']
#
#  conv_dw_2 (DepthwiseConv2D  (None, 56, 56, 12)           108       ['conv_pad_2[0][0]']
#  )
#
#  conv_dw_2_bn (BatchNormali  (None, 56, 56, 12)           48        ['conv_dw_2[0][0]']
#  zation)
#
#  conv_dw_2_Prelu (PReLU)     (None, 56, 56, 12)           37632     ['conv_dw_2_bn[0][0]']
#
#  conv_pw_2 (Conv2D)          (None, 56, 56, 16)           192       ['conv_dw_2_Prelu[0][0]']
#
#  conv_pw_2_bn (BatchNormali  (None, 56, 56, 16)           64        ['conv_pw_2[0][0]']
#  zation)
#
#  conv_pw_2_relu (Activation  (None, 56, 56, 16)           0         ['conv_pw_2_bn[0][0]']
#  )
#
#  squeeze_glo_avg_2 (GlobalA  (None, 16)                   0         ['conv_pw_2_relu[0][0]']
#  veragePooling2D)
#
#  squeeze_squ_2 (Dense)       (None, 1)                    16        ['squeeze_glo_avg_2[0][0]']
#
#  squeeze_exci_2 (Dense)      (None, 16)                   16        ['squeeze_squ_2[0][0]']
#
#  squeeze_scale_2 (Multiply)  (None, 56, 56, 16)           0         ['conv_pw_2_relu[0][0]',
#                                                                      'squeeze_exci_2[0][0]']
#
#  activation (Activation)     (None, 56, 56, 16)           0         ['squeeze_scale_2[0][0]']
#
#  conv_pad_3 (ZeroPadding2D)  (None, 58, 58, 16)           0         ['activation[0][0]']
#
#  conv_dw_3 (DepthwiseConv2D  (None, 56, 56, 16)           144       ['conv_pad_3[0][0]']
#  )
#
#  conv_dw_3_bn (BatchNormali  (None, 56, 56, 16)           64        ['conv_dw_3[0][0]']
#  zation)
#
#  conv_dw_3_Prelu (PReLU)     (None, 56, 56, 16)           50176     ['conv_dw_3_bn[0][0]']
#
#  conv_pw_3 (Conv2D)          (None, 56, 56, 48)           768       ['conv_dw_3_Prelu[0][0]']
#
#  conv_pw_3_bn (BatchNormali  (None, 56, 56, 48)           192       ['conv_pw_3[0][0]']
#  zation)
#
#  conv_pw_3_relu (Activation  (None, 56, 56, 48)           0         ['conv_pw_3_bn[0][0]']
#  )
#
#  squeeze_glo_avg_3 (GlobalA  (None, 48)                   0         ['conv_pw_3_relu[0][0]']
#  veragePooling2D)
#
#  squeeze_squ_3 (Dense)       (None, 3)                    144       ['squeeze_glo_avg_3[0][0]']
#
#  squeeze_exci_3 (Dense)      (None, 48)                   144       ['squeeze_squ_3[0][0]']
#
#  squeeze_scale_3 (Multiply)  (None, 56, 56, 48)           0         ['conv_pw_3_relu[0][0]',
#                                                                      'squeeze_exci_3[0][0]']
#
#  activation_1 (Activation)   (None, 56, 56, 48)           0         ['squeeze_scale_3[0][0]']
#
#  conv_4 (Conv2D)             (None, 56, 56, 24)           1152      ['activation_1[0][0]']
#
#  conv_4_bn (BatchNormalizat  (None, 56, 56, 24)           96        ['conv_4[0][0]']
#  ion)
#
#  conv_4_act (Activation)     (None, 56, 56, 24)           0         ['conv_4_bn[0][0]']
#
#  average_pooling2d (Average  (None, 28, 28, 24)           0         ['conv_4_act[0][0]']
#  Pooling2D)
#
#  average_pooling2d_1 (Avera  (None, 28, 28, 24)           0         ['conv_4_act[0][0]']
#  gePooling2D)
#
#  activation_2 (Activation)   (None, 28, 28, 24)           0         ['average_pooling2d[0][0]']
#
#  activation_4 (Activation)   (None, 28, 28, 24)           0         ['average_pooling2d_1[0][0]']
#
#  conv_pad_4_1 (ZeroPadding2  (None, 30, 30, 24)           0         ['activation_2[0][0]']
#  D)
#
#  conv_pad_4_2 (ZeroPadding2  (None, 32, 32, 24)           0         ['activation_4[0][0]']
#  D)
#
#  conv_dw_4_1 (DepthwiseConv  (None, 28, 28, 24)           216       ['conv_pad_4_1[0][0]']
#  2D)
#
#  conv_dw_4_2 (DepthwiseConv  (None, 28, 28, 24)           600       ['conv_pad_4_2[0][0]']
#  2D)
#
#  conv_dw_4_1_bn (BatchNorma  (None, 28, 28, 24)           96        ['conv_dw_4_1[0][0]']
#  lization)
#
#  conv_dw_4_2_bn (BatchNorma  (None, 28, 28, 24)           96        ['conv_dw_4_2[0][0]']
#  lization)
#
#  conv_dw_4_1_Prelu (PReLU)   (None, 28, 28, 24)           18816     ['conv_dw_4_1_bn[0][0]']
#
#  conv_dw_4_2_Prelu (PReLU)   (None, 28, 28, 24)           18816     ['conv_dw_4_2_bn[0][0]']
#
#  conv_pw_4_1 (Conv2D)        (None, 28, 28, 24)           576       ['conv_dw_4_1_Prelu[0][0]']
#
#  conv_pw_4_2 (Conv2D)        (None, 28, 28, 24)           576       ['conv_dw_4_2_Prelu[0][0]']
#
#  conv_pw_4_1_bn (BatchNorma  (None, 28, 28, 24)           96        ['conv_pw_4_1[0][0]']
#  lization)
#
#  conv_pw_4_2_bn (BatchNorma  (None, 28, 28, 24)           96        ['conv_pw_4_2[0][0]']
#  lization)
#
#  conv_pw_4_1_relu (Activati  (None, 28, 28, 24)           0         ['conv_pw_4_1_bn[0][0]']
#  on)
#
#  conv_pw_4_2_relu (Activati  (None, 28, 28, 24)           0         ['conv_pw_4_2_bn[0][0]']
#  on)
#
#  s2_block_4_1 (UpSampling2D  (None, 56, 56, 24)           0         ['conv_pw_4_1_relu[0][0]']
#  )
#
#  s2_block_4_2 (UpSampling2D  (None, 56, 56, 24)           0         ['conv_pw_4_2_relu[0][0]']
#  )
#
#  batch_normalization (Batch  (None, 56, 56, 24)           96        ['s2_block_4_1[0][0]']
#  Normalization)
#
#  batch_normalization_1 (Bat  (None, 56, 56, 24)           96        ['s2_block_4_2[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 56, 56, 24)           0         ['batch_normalization[0][0]']
#
#  activation_5 (Activation)   (None, 56, 56, 24)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  concatenate (Concatenate)   (None, 56, 56, 48)           0         ['activation_3[0][0]',
#                                                                      'activation_5[0][0]']
#
#  add (Add)                   (None, 56, 56, 48)           0         ['activation_1[0][0]',
#                                                                      'concatenate[0][0]']
#
#  p_re_lu (PReLU)             (None, 56, 56, 48)           150528    ['add[0][0]']
#
#  conv_5 (Conv2D)             (None, 56, 56, 24)           1152      ['p_re_lu[0][0]']
#
#  conv_5_bn (BatchNormalizat  (None, 56, 56, 24)           96        ['conv_5[0][0]']
#  ion)
#
#  conv_5_act (Activation)     (None, 56, 56, 24)           0         ['conv_5_bn[0][0]']
#
#  average_pooling2d_2 (Avera  (None, 28, 28, 24)           0         ['conv_5_act[0][0]']
#  gePooling2D)
#
#  average_pooling2d_3 (Avera  (None, 28, 28, 24)           0         ['conv_5_act[0][0]']
#  gePooling2D)
#
#  activation_6 (Activation)   (None, 28, 28, 24)           0         ['average_pooling2d_2[0][0]']
#
#  activation_8 (Activation)   (None, 28, 28, 24)           0         ['average_pooling2d_3[0][0]']
#
#  conv_pad_5_1 (ZeroPadding2  (None, 30, 30, 24)           0         ['activation_6[0][0]']
#  D)
#
#  conv_pad_5_2 (ZeroPadding2  (None, 30, 30, 24)           0         ['activation_8[0][0]']
#  D)
#
#  conv_dw_5_1 (DepthwiseConv  (None, 28, 28, 24)           216       ['conv_pad_5_1[0][0]']
#  2D)
#
#  conv_dw_5_2 (DepthwiseConv  (None, 28, 28, 24)           216       ['conv_pad_5_2[0][0]']
#  2D)
#
#  conv_dw_5_1_bn (BatchNorma  (None, 28, 28, 24)           96        ['conv_dw_5_1[0][0]']
#  lization)
#
#  conv_dw_5_2_bn (BatchNorma  (None, 28, 28, 24)           96        ['conv_dw_5_2[0][0]']
#  lization)
#
#  conv_dw_5_1_Prelu (PReLU)   (None, 28, 28, 24)           18816     ['conv_dw_5_1_bn[0][0]']
#
#  conv_dw_5_2_Prelu (PReLU)   (None, 28, 28, 24)           18816     ['conv_dw_5_2_bn[0][0]']
#
#  conv_pw_5_1 (Conv2D)        (None, 28, 28, 24)           576       ['conv_dw_5_1_Prelu[0][0]']
#
#  conv_pw_5_2 (Conv2D)        (None, 28, 28, 24)           576       ['conv_dw_5_2_Prelu[0][0]']
#
#  conv_pw_5_1_bn (BatchNorma  (None, 28, 28, 24)           96        ['conv_pw_5_1[0][0]']
#  lization)
#
#  conv_pw_5_2_bn (BatchNorma  (None, 28, 28, 24)           96        ['conv_pw_5_2[0][0]']
#  lization)
#
#  conv_pw_5_1_relu (Activati  (None, 28, 28, 24)           0         ['conv_pw_5_1_bn[0][0]']
#  on)
#
#  conv_pw_5_2_relu (Activati  (None, 28, 28, 24)           0         ['conv_pw_5_2_bn[0][0]']
#  on)
#
#  s2_block_5_1 (UpSampling2D  (None, 56, 56, 24)           0         ['conv_pw_5_1_relu[0][0]']
#  )
#
#  s2_block_5_2 (UpSampling2D  (None, 56, 56, 24)           0         ['conv_pw_5_2_relu[0][0]']
#  )
#
#  batch_normalization_2 (Bat  (None, 56, 56, 24)           96        ['s2_block_5_1[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 56, 56, 24)           96        ['s2_block_5_2[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 56, 56, 24)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 56, 56, 24)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  concatenate_1 (Concatenate  (None, 56, 56, 48)           0         ['activation_7[0][0]',
#  )                                                                   'activation_9[0][0]']
#
#  add_1 (Add)                 (None, 56, 56, 48)           0         ['p_re_lu[0][0]',
#                                                                      'concatenate_1[0][0]']
#
#  p_re_lu_1 (PReLU)           (None, 56, 56, 48)           150528    ['add_1[0][0]']
#
#  concat_2_5 (Concatenate)    (None, 56, 56, 64)           0         ['activation[0][0]',
#                                                                      'p_re_lu_1[0][0]']
#
#  conv_pad_6 (ZeroPadding2D)  (None, 58, 58, 64)           0         ['concat_2_5[0][0]']
#
#  conv_dw_6 (DepthwiseConv2D  (None, 28, 28, 64)           576       ['conv_pad_6[0][0]']
#  )
#
#  conv_dw_6_bn (BatchNormali  (None, 28, 28, 64)           256       ['conv_dw_6[0][0]']
#  zation)
#
#  conv_dw_6_Prelu (PReLU)     (None, 28, 28, 64)           50176     ['conv_dw_6_bn[0][0]']
#
#  conv_pw_6 (Conv2D)          (None, 28, 28, 48)           3072      ['conv_dw_6_Prelu[0][0]']
#
#  conv_pw_6_bn (BatchNormali  (None, 28, 28, 48)           192       ['conv_pw_6[0][0]']
#  zation)
#
#  conv_pw_6_relu (Activation  (None, 28, 28, 48)           0         ['conv_pw_6_bn[0][0]']
#  )
#
#  squeeze_glo_avg_6 (GlobalA  (None, 48)                   0         ['conv_pw_6_relu[0][0]']
#  veragePooling2D)
#
#  squeeze_squ_6 (Dense)       (None, 3)                    144       ['squeeze_glo_avg_6[0][0]']
#
#  squeeze_exci_6 (Dense)      (None, 48)                   144       ['squeeze_squ_6[0][0]']
#
#  squeeze_scale_6 (Multiply)  (None, 28, 28, 48)           0         ['conv_pw_6_relu[0][0]',
#                                                                      'squeeze_exci_6[0][0]']
#
#  activation_10 (Activation)  (None, 28, 28, 48)           0         ['squeeze_scale_6[0][0]']
#
#  conv_pad_7 (ZeroPadding2D)  (None, 30, 30, 48)           0         ['activation_10[0][0]']
#
#  conv_dw_7 (DepthwiseConv2D  (None, 28, 28, 48)           432       ['conv_pad_7[0][0]']
#  )
#
#  conv_dw_7_bn (BatchNormali  (None, 28, 28, 48)           192       ['conv_dw_7[0][0]']
#  zation)
#
#  conv_dw_7_Prelu (PReLU)     (None, 28, 28, 48)           37632     ['conv_dw_7_bn[0][0]']
#
#  conv_pw_7 (Conv2D)          (None, 28, 28, 96)           4608      ['conv_dw_7_Prelu[0][0]']
#
#  conv_pw_7_bn (BatchNormali  (None, 28, 28, 96)           384       ['conv_pw_7[0][0]']
#  zation)
#
#  conv_pw_7_relu (Activation  (None, 28, 28, 96)           0         ['conv_pw_7_bn[0][0]']
#  )
#
#  squeeze_glo_avg_7 (GlobalA  (None, 96)                   0         ['conv_pw_7_relu[0][0]']
#  veragePooling2D)
#
#  squeeze_squ_7 (Dense)       (None, 6)                    576       ['squeeze_glo_avg_7[0][0]']
#
#  squeeze_exci_7 (Dense)      (None, 96)                   576       ['squeeze_squ_7[0][0]']
#
#  squeeze_scale_7 (Multiply)  (None, 28, 28, 96)           0         ['conv_pw_7_relu[0][0]',
#                                                                      'squeeze_exci_7[0][0]']
#
#  activation_11 (Activation)  (None, 28, 28, 96)           0         ['squeeze_scale_7[0][0]']
#
#  conv_8 (Conv2D)             (None, 28, 28, 48)           4608      ['activation_11[0][0]']
#
#  conv_8_bn (BatchNormalizat  (None, 28, 28, 48)           192       ['conv_8[0][0]']
#  ion)
#
#  conv_8_act (Activation)     (None, 28, 28, 48)           0         ['conv_8_bn[0][0]']
#
#  average_pooling2d_4 (Avera  (None, 14, 14, 48)           0         ['conv_8_act[0][0]']
#  gePooling2D)
#
#  average_pooling2d_5 (Avera  (None, 14, 14, 48)           0         ['conv_8_act[0][0]']
#  gePooling2D)
#
#  activation_12 (Activation)  (None, 14, 14, 48)           0         ['average_pooling2d_4[0][0]']
#
#  activation_14 (Activation)  (None, 14, 14, 48)           0         ['average_pooling2d_5[0][0]']
#
#  conv_pad_8_1 (ZeroPadding2  (None, 16, 16, 48)           0         ['activation_12[0][0]']
#  D)
#
#  conv_pad_8_2 (ZeroPadding2  (None, 18, 18, 48)           0         ['activation_14[0][0]']
#  D)
#
#  conv_dw_8_1 (DepthwiseConv  (None, 14, 14, 48)           432       ['conv_pad_8_1[0][0]']
#  2D)
#
#  conv_dw_8_2 (DepthwiseConv  (None, 14, 14, 48)           1200      ['conv_pad_8_2[0][0]']
#  2D)
#
#  conv_dw_8_1_bn (BatchNorma  (None, 14, 14, 48)           192       ['conv_dw_8_1[0][0]']
#  lization)
#
#  conv_dw_8_2_bn (BatchNorma  (None, 14, 14, 48)           192       ['conv_dw_8_2[0][0]']
#  lization)
#
#  conv_dw_8_1_Prelu (PReLU)   (None, 14, 14, 48)           9408      ['conv_dw_8_1_bn[0][0]']
#
#  conv_dw_8_2_Prelu (PReLU)   (None, 14, 14, 48)           9408      ['conv_dw_8_2_bn[0][0]']
#
#  conv_pw_8_1 (Conv2D)        (None, 14, 14, 48)           2304      ['conv_dw_8_1_Prelu[0][0]']
#
#  conv_pw_8_2 (Conv2D)        (None, 14, 14, 48)           2304      ['conv_dw_8_2_Prelu[0][0]']
#
#  conv_pw_8_1_bn (BatchNorma  (None, 14, 14, 48)           192       ['conv_pw_8_1[0][0]']
#  lization)
#
#  conv_pw_8_2_bn (BatchNorma  (None, 14, 14, 48)           192       ['conv_pw_8_2[0][0]']
#  lization)
#
#  conv_pw_8_1_relu (Activati  (None, 14, 14, 48)           0         ['conv_pw_8_1_bn[0][0]']
#  on)
#
#  conv_pw_8_2_relu (Activati  (None, 14, 14, 48)           0         ['conv_pw_8_2_bn[0][0]']
#  on)
#
#  s2_block_8_1 (UpSampling2D  (None, 28, 28, 48)           0         ['conv_pw_8_1_relu[0][0]']
#  )
#
#  s2_block_8_2 (UpSampling2D  (None, 28, 28, 48)           0         ['conv_pw_8_2_relu[0][0]']
#  )
#
#  batch_normalization_4 (Bat  (None, 28, 28, 48)           192       ['s2_block_8_1[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 28, 28, 48)           192       ['s2_block_8_2[0][0]']
#  chNormalization)
#
#  activation_13 (Activation)  (None, 28, 28, 48)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  activation_15 (Activation)  (None, 28, 28, 48)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  concatenate_2 (Concatenate  (None, 28, 28, 96)           0         ['activation_13[0][0]',
#  )                                                                   'activation_15[0][0]']
#
#  add_2 (Add)                 (None, 28, 28, 96)           0         ['activation_11[0][0]',
#                                                                      'concatenate_2[0][0]']
#
#  p_re_lu_2 (PReLU)           (None, 28, 28, 96)           75264     ['add_2[0][0]']
#
#  conv_9 (Conv2D)             (None, 28, 28, 48)           4608      ['p_re_lu_2[0][0]']
#
#  conv_9_bn (BatchNormalizat  (None, 28, 28, 48)           192       ['conv_9[0][0]']
#  ion)
#
#  conv_9_act (Activation)     (None, 28, 28, 48)           0         ['conv_9_bn[0][0]']
#
#  average_pooling2d_6 (Avera  (None, 14, 14, 48)           0         ['conv_9_act[0][0]']
#  gePooling2D)
#
#  average_pooling2d_7 (Avera  (None, 14, 14, 48)           0         ['conv_9_act[0][0]']
#  gePooling2D)
#
#  activation_16 (Activation)  (None, 14, 14, 48)           0         ['average_pooling2d_6[0][0]']
#
#  activation_18 (Activation)  (None, 14, 14, 48)           0         ['average_pooling2d_7[0][0]']
#
#  conv_pad_9_1 (ZeroPadding2  (None, 16, 16, 48)           0         ['activation_16[0][0]']
#  D)
#
#  conv_pad_9_2 (ZeroPadding2  (None, 16, 16, 48)           0         ['activation_18[0][0]']
#  D)
#
#  conv_dw_9_1 (DepthwiseConv  (None, 14, 14, 48)           432       ['conv_pad_9_1[0][0]']
#  2D)
#
#  conv_dw_9_2 (DepthwiseConv  (None, 14, 14, 48)           432       ['conv_pad_9_2[0][0]']
#  2D)
#
#  conv_dw_9_1_bn (BatchNorma  (None, 14, 14, 48)           192       ['conv_dw_9_1[0][0]']
#  lization)
#
#  conv_dw_9_2_bn (BatchNorma  (None, 14, 14, 48)           192       ['conv_dw_9_2[0][0]']
#  lization)
#
#  conv_dw_9_1_Prelu (PReLU)   (None, 14, 14, 48)           9408      ['conv_dw_9_1_bn[0][0]']
#
#  conv_dw_9_2_Prelu (PReLU)   (None, 14, 14, 48)           9408      ['conv_dw_9_2_bn[0][0]']
#
#  conv_pw_9_1 (Conv2D)        (None, 14, 14, 48)           2304      ['conv_dw_9_1_Prelu[0][0]']
#
#  conv_pw_9_2 (Conv2D)        (None, 14, 14, 48)           2304      ['conv_dw_9_2_Prelu[0][0]']
#
#  conv_pw_9_1_bn (BatchNorma  (None, 14, 14, 48)           192       ['conv_pw_9_1[0][0]']
#  lization)
#
#  conv_pw_9_2_bn (BatchNorma  (None, 14, 14, 48)           192       ['conv_pw_9_2[0][0]']
#  lization)
#
#  conv_pw_9_1_relu (Activati  (None, 14, 14, 48)           0         ['conv_pw_9_1_bn[0][0]']
#  on)
#
#  conv_pw_9_2_relu (Activati  (None, 14, 14, 48)           0         ['conv_pw_9_2_bn[0][0]']
#  on)
#
#  s2_block_9_1 (UpSampling2D  (None, 28, 28, 48)           0         ['conv_pw_9_1_relu[0][0]']
#  )
#
#  s2_block_9_2 (UpSampling2D  (None, 28, 28, 48)           0         ['conv_pw_9_2_relu[0][0]']
#  )
#
#  batch_normalization_6 (Bat  (None, 28, 28, 48)           192       ['s2_block_9_1[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 28, 28, 48)           192       ['s2_block_9_2[0][0]']
#  chNormalization)
#
#  activation_17 (Activation)  (None, 28, 28, 48)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  activation_19 (Activation)  (None, 28, 28, 48)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  concatenate_3 (Concatenate  (None, 28, 28, 96)           0         ['activation_17[0][0]',
#  )                                                                   'activation_19[0][0]']
#
#  add_3 (Add)                 (None, 28, 28, 96)           0         ['p_re_lu_2[0][0]',
#                                                                      'concatenate_3[0][0]']
#
#  p_re_lu_3 (PReLU)           (None, 28, 28, 96)           75264     ['add_3[0][0]']
#
#  conv_10 (Conv2D)            (None, 28, 28, 48)           4608      ['p_re_lu_3[0][0]']
#
#  conv_10_bn (BatchNormaliza  (None, 28, 28, 48)           192       ['conv_10[0][0]']
#  tion)
#
#  conv_10_act (Activation)    (None, 28, 28, 48)           0         ['conv_10_bn[0][0]']
#
#  average_pooling2d_8 (Avera  (None, 14, 14, 48)           0         ['conv_10_act[0][0]']
#  gePooling2D)
#
#  average_pooling2d_9 (Avera  (None, 14, 14, 48)           0         ['conv_10_act[0][0]']
#  gePooling2D)
#
#  activation_20 (Activation)  (None, 14, 14, 48)           0         ['average_pooling2d_8[0][0]']
#
#  activation_22 (Activation)  (None, 14, 14, 48)           0         ['average_pooling2d_9[0][0]']
#
# ...
#  conv_15_bn (BatchNormaliza  (None, 28, 28, 48)           192       ['conv_15[0][0]']
#  tion)
#
#  conv_15_act (Activation)    (None, 28, 28, 48)           0         ['conv_15_bn[0][0]']
#
#  average_pooling2d_18 (Aver  (None, 14, 14, 48)           0         ['conv_15_act[0][0]']
#  agePooling2D)
#
#  average_pooling2d_19 (Aver  (None, 14, 14, 48)           0         ['conv_15_act[0][0]']
#  agePooling2D)
#
#  activation_40 (Activation)  (None, 14, 14, 48)           0         ['average_pooling2d_18[0][0]']
#
#  activation_42 (Activation)  (None, 14, 14, 48)           0         ['average_pooling2d_19[0][0]']
#
#  conv_pad_15_1 (ZeroPadding  (None, 16, 16, 48)           0         ['activation_40[0][0]']
#  2D)
#
#  conv_pad_15_2 (ZeroPadding  (None, 18, 18, 48)           0         ['activation_42[0][0]']
#  2D)
#
#  conv_dw_15_1 (DepthwiseCon  (None, 14, 14, 48)           432       ['conv_pad_15_1[0][0]']
#  v2D)
#
#  conv_dw_15_2 (DepthwiseCon  (None, 14, 14, 48)           1200      ['conv_pad_15_2[0][0]']
#  v2D)
#
#  conv_dw_15_1_bn (BatchNorm  (None, 14, 14, 48)           192       ['conv_dw_15_1[0][0]']
#  alization)
#
#  conv_dw_15_2_bn (BatchNorm  (None, 14, 14, 48)           192       ['conv_dw_15_2[0][0]']
#  alization)
#
#  conv_dw_15_1_Prelu (PReLU)  (None, 14, 14, 48)           9408      ['conv_dw_15_1_bn[0][0]']
#
#  conv_dw_15_2_Prelu (PReLU)  (None, 14, 14, 48)           9408      ['conv_dw_15_2_bn[0][0]']
#
#  conv_pw_15_1 (Conv2D)       (None, 14, 14, 48)           2304      ['conv_dw_15_1_Prelu[0][0]']
#
#  conv_pw_15_2 (Conv2D)       (None, 14, 14, 48)           2304      ['conv_dw_15_2_Prelu[0][0]']
#
#  conv_pw_15_1_bn (BatchNorm  (None, 14, 14, 48)           192       ['conv_pw_15_1[0][0]']
#  alization)
#
#  conv_pw_15_2_bn (BatchNorm  (None, 14, 14, 48)           192       ['conv_pw_15_2[0][0]']
#  alization)
#
#  conv_pw_15_1_relu (Activat  (None, 14, 14, 48)           0         ['conv_pw_15_1_bn[0][0]']
#  ion)
#
#  conv_pw_15_2_relu (Activat  (None, 14, 14, 48)           0         ['conv_pw_15_2_bn[0][0]']
#  ion)
#
#  s2_block_15_1 (UpSampling2  (None, 28, 28, 48)           0         ['conv_pw_15_1_relu[0][0]']
#  D)
#
#  s2_block_15_2 (UpSampling2  (None, 28, 28, 48)           0         ['conv_pw_15_2_relu[0][0]']
#  D)
#
#  batch_normalization_18 (Ba  (None, 28, 28, 48)           192       ['s2_block_15_1[0][0]']
#  tchNormalization)
#
#  batch_normalization_19 (Ba  (None, 28, 28, 48)           192       ['s2_block_15_2[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, 28, 28, 48)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  activation_43 (Activation)  (None, 28, 28, 48)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  concatenate_9 (Concatenate  (None, 28, 28, 96)           0         ['activation_41[0][0]',
#  )                                                                   'activation_43[0][0]']
#
#  add_9 (Add)                 (None, 28, 28, 96)           0         ['p_re_lu_8[0][0]',
#                                                                      'concatenate_9[0][0]']
#
#  p_re_lu_9 (PReLU)           (None, 28, 28, 96)           75264     ['add_9[0][0]']
#
#  concat_16_7 (Concatenate)   (None, 28, 28, 144)          0         ['p_re_lu_9[0][0]',
#                                                                      'activation_10[0][0]']
#
#  activation_44 (Activation)  (None, 28, 28, 144)          0         ['concat_16_7[0][0]']
#
#  conv_pw_16 (Conv2D)         (None, 28, 28, 2)            288       ['activation_44[0][0]']
#
#  conv_pw_16_bn (BatchNormal  (None, 28, 28, 2)            8         ['conv_pw_16[0][0]']
#  ization)
#
#  conv_pw_16_relu (Activatio  (None, 28, 28, 2)            0         ['conv_pw_16_bn[0][0]']
#  n)
#
#  activation_45 (Activation)  (None, 28, 28, 2)            0         ['conv_pw_16_relu[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 56, 56, 2)            0         ['activation_45[0][0]']
#  D)
#
#  batch_normalization_20 (Ba  (None, 56, 56, 2)            8         ['up_sampling2d[0][0]']
#  tchNormalization)
#
#  conv_pw_18 (Conv2D)         (None, 56, 56, 2)            96        ['p_re_lu_1[0][0]']
#
#  activation_46 (Activation)  (None, 56, 56, 2)            0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv_pw_18_bn (BatchNormal  (None, 56, 56, 2)            8         ['conv_pw_18[0][0]']
#  ization)
#
#  tf.math.reduce_max (TFOpLa  (None, 56, 56, 1)            0         ['activation_46[0][0]']
#  mbda)
#
#  conv_pw_18_relu (Activatio  (None, 56, 56, 2)            0         ['conv_pw_18_bn[0][0]']
#  n)
#
#  information_blocking_decod  (None, 56, 56, 1)            0         ['tf.math.reduce_max[0][0]']
#  er (Lambda)
#
#  multiply (Multiply)         (None, 56, 56, 2)            0         ['conv_pw_18_relu[0][0]',
#                                                                      'information_blocking_decoder
#                                                                     [0][0]']
#
#  activation_47 (Activation)  (None, 56, 56, 2)            0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  add_10 (Add)                (None, 56, 56, 2)            0         ['multiply[0][0]',
#                                                                      'activation_47[0][0]']
#
#  activation_48 (Activation)  (None, 56, 56, 2)            0         ['add_10[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 112, 112, 2)          0         ['activation_48[0][0]']
#  g2D)
#
#  batch_normalization_21 (Ba  (None, 112, 112, 2)          8         ['up_sampling2d_1[0][0]']
#  tchNormalization)
#
#  activation_49 (Activation)  (None, 112, 112, 2)          0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv_19 (Conv2D)            (None, 112, 112, 2)          4         ['activation_49[0][0]']
#
#  conv_19_bn (BatchNormaliza  (None, 112, 112, 2)          8         ['conv_19[0][0]']
#  tion)
#
#  conv_19_act (Activation)    (None, 112, 112, 2)          0         ['conv_19_bn[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 224, 224, 2)          0         ['conv_19_act[0][0]']
#  g2D)
#
#  batch_normalization_22 (Ba  (None, 224, 224, 2)          8         ['up_sampling2d_2[0][0]']
#  tchNormalization)
#
#  activation_50 (Activation)  (None, 224, 224, 2)          0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  reshape (Reshape)           (None, 50176, 2)             0         ['activation_50[0][0]']
#
#  activation_51 (Activation)  (None, 50176, 2)             0         ['reshape[0][0]']
#
# ==================================================================================================
# Total params: 1421636 (5.42 MB)
# Trainable params: 1414844 (5.40 MB)
# Non-trainable params: 6792 (26.53 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Dataset Generation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !ls
# Out:
#  baidu_V1		   'Thao tác dữ liệu'			     Untitled1.ipynb
#  baidu_V2		    trained_weight			     Untitled3.ipynb
#  Nukki.zip		   'Transfer learning + Data Agumentation'   Untitled4.ipynb
#  SINet			    unet				     Untitled7.ipynb
#  sinet-segmentation.ipynb  'Unet for image_segmentation'	     UpSampling.ipynb

# %%
files = pd.read_csv("./baidu_V1/train.txt", header=None)[0]

# %%
files.values
# Out:
# array(['501.png', '502.png', '503.png', ..., '5379.png', '5380.png',
#        '5381.png'], dtype=object)

# %%
class DataAugmentation:
    def __init__(self):
        self.IMAGE_AUGMENTATION_SEQUENCE = None
        self.IMAGE_AUGMENTATION_NUM_TRIES = 10
        self.loaded_augmentation_name = ""

        self.augmentation_functions = {
            "aug_all": self._load_augmentation_aug_all,
            "aug_geometric": self._load_augmentation_aug_geometric,
            "aug_non_geometric": self._load_augmentation_aug_non_geometric,
        }

    def _load_augmentation_aug_geometric(self):
        return iaa.Sequential([
            iaa.Sometimes(0.5, iaa.Fliplr()),
            iaa.Sometimes(0.5, iaa.Rotate((-45, 45))),
            iaa.Sometimes(0.5, iaa.Affine(
                scale={"x": (0.5, 1.5), "y": (0.5, 1.5)},
                order=[0, 1],
                mode='constant',
                cval=(0, 255),
            )),
            iaa.Sometimes(0.5, iaa.Affine(
                translate_percent={"x": (-0.25, 0.25), "y": (-0.25, 0.25)},
                order=[0, 1],
                mode='constant',
                cval=(0, 255),
            )),
        ])

    def _load_augmentation_aug_non_geometric(self):
        return iaa.Sequential([
            iaa.Sometimes(0.5, iaa.AdditiveGaussianNoise(loc=0, scale=(0.0, 0.05*255), per_channel=0.5)),
            iaa.Sometimes(0.5, iaa.OneOf([
                iaa.GaussianBlur(sigma=(0.0, 3.0)),
                iaa.GaussianBlur(sigma=(0.0, 5.0))
            ])),
            iaa.Sometimes(0.5, iaa.MultiplyAndAddToBrightness(mul=(0.4, 1.7))),
            iaa.Sometimes(0.5, iaa.GammaContrast((0.4, 1.7))),
            iaa.Sometimes(0.5, iaa.Multiply((0.4, 1.7), per_channel=0.5)),
            iaa.Sometimes(0.5, iaa.MultiplyHue((0.4, 1.7))),
            iaa.Sometimes(0.5, iaa.MultiplyHueAndSaturation((0.4, 1.7), per_channel=True)),
            iaa.Sometimes(0.5, iaa.LinearContrast((0.4, 1.7), per_channel=0.5))
        ])

    def _load_augmentation_aug_all(self):
        return iaa.OneOf([
            iaa.Sometimes(0.5, self._load_augmentation_aug_geometric()),
            iaa.Sometimes(0.5, self._load_augmentation_aug_non_geometric())
        ])

    def _load_aug_by_name(self, aug_name="aug_all"):
        if not len(self.loaded_augmentation_name):
            self.loaded_augmentation_name = aug_name
            self.IMAGE_AUGMENTATION_SEQUENCE = self.augmentation_functions[aug_name]()

        return self.IMAGE_AUGMENTATION_SEQUENCE

# %%
DATA_DIR = "./"
TRAIN_ANNO_FILE1 = os.path.join(DATA_DIR, "baidu_V1/train.txt")
TRAIN_ANNO_FILE2 = os.path.join(DATA_DIR, "baidu_V2/train.txt")
VAL_ANNO_FILE1 = os.path.join(DATA_DIR, "baidu_V1/val.txt")
VAL_ANNO_FILE2 = os.path.join(DATA_DIR, "baidu_V2/val.txt")

# %%
class DataGenerator:
    def __init__(self,
                 data_dir,
                 anno_paths,
                 augment_func,
                 img_height=IMG_HEIGHT,
                 img_width=IMG_WIDTH,
                 img_channel=IMG_CHANNEL,
                 batch_size=36,
                 n_classes=N_CLASSES,
                 augmentation=True,
                 task="train"):

        self.data_dir = data_dir
        self.anno_paths = anno_paths
        self.augment_func = augment_func
        self.batch_size = batch_size
        self.task = task
        self.current_index = 0
#         self.current_test = 0
        self.img_height = img_height
        self.img_width = img_width
        self.img_channel = img_channel
        self.n_classes = n_classes
        self.augmentation = augmentation
        self.image_paths, self.label_paths = self.load_image_paths()

    def load_image_paths(self):
        image_paths = []
        label_paths = []

        for anno_path in self.anno_paths:
            anno_dir = os.path.dirname(anno_path)
            df_file_names = pd.read_csv(anno_path, header=None)
            file_names = df_file_names[0].values

            for fn in file_names:
                if "DS_Store" in fn: continue
                img_train_dir = os.path.join(anno_dir, "input")
                img_label_dir = os.path.join(anno_dir, "target")
                img_train_path = os.path.join(img_train_dir, fn)
                img_label_path = os.path.join(img_label_dir, fn)

                image_paths.append(img_train_path)
                label_paths.append(img_label_path)

        image_paths = np.array(image_paths)
        label_paths = np.array(label_paths)

        return image_paths, label_paths

    def get_n_examples(self):
        return len(self.image_paths)

    def load_image(self, img_path):
        image = cv2.imread(img_path)
#         image = image[..., ::-1]
        return image

    def parse_label(self, seg_image):
        label = seg_image
        label = label[:, :, 0]
        seg = np.zeros((self.img_height, self.img_width, self.n_classes))

        for i in range(self.n_classes):
            seg[:, :, i] = (label == i).astype("int")

        seg = np.reshape(seg, (-1, self.n_classes))
        return seg

    def load_batch_pair_in_pair(self, img_paths, label_paths):
        images = []
        segs = []
        preprocessors = [self.resize_img, self.mean_substraction]

        for i in range(len(img_paths)):
            image = self.load_image(img_paths[i])
#             image = self.preprocessing(image, preprocessors)

            seg = self.load_image(label_paths[i])
#             seg = self.preprocessing(seg, [self.resize_img])
#             print(seg.dtype)
#             seg = seg.astype(np.uint8)
#             seg = self.parse_label(seg)
#             seg = np.argmax(seg, axis=-1).astype(np.int32)
            segmap = SegmentationMapsOnImage(seg, shape=image.shape)

            if self.augmentation:
                image, segmap = self.augment_func(image=image, segmentation_maps=segmap)

            seg[:, :, 0] = segmap.get_arr_int()
            image = self.preprocessing(image, preprocessors)

#             seg = self.preprocessing(seg, [self.resize_img])
            seg = self.resize_img(seg, interpolation=cv2.INTER_NEAREST)
            seg = seg /255
            seg[seg > 0.5] = 1
            seg[seg <= 0.5] = 0
            seg = self.parse_label(seg)

            images.append(image)
            segs.append(seg)

            if self.augmentation:
              images, segs = self.augment_func(images=images, segmentation_maps=segs)
        return np.array(images), np.array(segs)


    def show_sample_image(self):
        idx = np.random.choice(len(self.image_paths), 1)[0]
        img_path = self.image_paths[idx]
        seg_path = self.label_paths[idx]

        img = self.load_image(img_path)
        seg = self.load_image(seg_path)
#         segmap = SegmentationMapsOnImage(seg[..., 0], shape=img.shape)
        segmap = SegmentationMapsOnImage(seg, shape=img.shape)

        img_aug, seg_aug = self.augment_func(image=img, segmentation_maps=segmap)

        ia.imshow(np.hstack([
            img[..., ::-1],
            seg
        ]))

#         seg[..., 0] = seg_aug.get_arr_int()
        seg = seg_aug.get_arr_int()
#         print(np.nonzero(seg[..., 0]))

#         non_index = np.nonzero(seg[..., 0])
#         for i in range(len(non_index[0])):
#             print(seg[..., 0][non_index[0][i], non_index[1][i]])

        ia.imshow(np.hstack([
            img_aug[..., ::-1],
            seg
        ]))

        seg = seg /255
        seg[seg < 0.5] = 0
        seg[seg >= 0.5] = 1

        ia.imshow(np.hstack([
            img_aug[..., ::-1],
            seg
        ]))

    def resize_img(self, image):
#         h, w = image.shape[:2]
#         print(h, w)
#         p_h, p_w = 0, 0

#         if h>w:
#             image = imutils.resize(image, width=self.img_width)
#             p_h = int((image.shape[0] - self.img_height) / 2)
#         else:
#             image = imutils.resize(image, height=self.img_height)
#             p_w = int((image.shape[1] - self.img_width) / 2)

#         image = image[p_w:image.shape[1]-p_w, p_h: image.shape[0]-p_h]
        image = cv2.resize(image, (self.img_height, self.img_width), interpolation=cv2.INTER_AREA)
        return image

    def mean_substraction(self, image, mean=[103.94, 116.78, 123.68], image_val=0.017):
        image = image.astype("float32")
        image[:, :, 0] -= mean[0]
        image[:, :, 1] -= mean[1]
        image[:, :, 2] -= mean[2]
        image *= image_val
        image = image[..., ::-1]

        return image

    def preprocessing(self, image, preprocessors):
        for p in preprocessors:
            image = p(image)

        return image

    def load_batch(self):
        if self.current_index + self.batch_size >= len(self.image_paths):
            self.current_index = 0
            self.image_paths, self.label_paths = shuffle(self.image_paths, self.label_paths, random_state=42)

        img_batch_paths = self.image_paths[self.current_index:self.current_index+self.batch_size]
        seg_batch_paths = self.label_paths[self.current_index:self.current_index+self.batch_size]
        self.current_index += self.batch_size
        inputs, segs = self.load_batch_pair_in_pair(img_batch_paths, seg_batch_paths)

        return inputs, segs

    def generate(self):
        while True:
            images, labels = self.load_batch()

            yield (images, labels)

# %%
data_aug = DataAugmentation()

# %%
aug = data_aug._load_aug_by_name()

# %%
cd ./Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
train_datagen = DataGenerator(DATA_DIR, [TRAIN_ANNO_FILE1, TRAIN_ANNO_FILE2], aug, batch_size=24)

# %%
train_datagen.get_n_examples()
# Out:
# 10160

# %%
train_datagen.label_paths
# Out:
# array(['./baidu_V1/target/501.png', './baidu_V1/target/502.png',
#        './baidu_V1/target/503.png', ..., './baidu_V2/target/26852.jpg',
#        './baidu_V2/target/17457.jpg', './baidu_V2/target/16749.jpg'],
#       dtype='<U27')

# %%
train_datagen.show_sample_image()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
val_datagen = DataGenerator(DATA_DIR, [VAL_ANNO_FILE1, VAL_ANNO_FILE2], aug, batch_size=24)

# %%
val_datagen.get_n_examples()
# Out:
# 600

# %%
val_datagen.label_paths
# Out:
# array(['./baidu_V1/target/0.png', './baidu_V1/target/1.png',
#        './baidu_V1/target/2.png', './baidu_V1/target/3.png',
#        './baidu_V1/target/4.png', './baidu_V1/target/5.png',
#        './baidu_V1/target/6.png', './baidu_V1/target/7.png',
#        './baidu_V1/target/8.png', './baidu_V1/target/9.png',
#        './baidu_V1/target/10.png', './baidu_V1/target/11.png',
#        './baidu_V1/target/12.png', './baidu_V1/target/13.png',
#        './baidu_V1/target/14.png', './baidu_V1/target/15.png',
#        './baidu_V1/target/16.png', './baidu_V1/target/17.png',
#        './baidu_V1/target/18.png', './baidu_V1/target/19.png',
#        './baidu_V1/target/20.png', './baidu_V1/target/21.png',
#        './baidu_V1/target/22.png', './baidu_V1/target/23.png',
#        './baidu_V1/target/24.png', './baidu_V1/target/25.png',
#        './baidu_V1/target/26.png', './baidu_V1/target/27.png',
#        './baidu_V1/target/28.png', './baidu_V1/target/29.png',
#        './baidu_V1/target/30.png', './baidu_V1/target/31.png',
#        './baidu_V1/target/32.png', './baidu_V1/target/33.png',
#        './baidu_V1/target/34.png', './baidu_V1/target/35.png',
#        './baidu_V1/target/36.png', './baidu_V1/target/37.png',
#        './baidu_V1/target/38.png', './baidu_V1/target/39.png',
#        './baidu_V1/target/40.png', './baidu_V1/target/41.png',
#        './baidu_V1/target/42.png', './baidu_V1/target/43.png',
#        './baidu_V1/target/44.png', './baidu_V1/target/45.png',
#        './baidu_V1/target/46.png', './baidu_V1/target/47.png',
#        './baidu_V1/target/48.png', './baidu_V1/target/49.png',
#        './baidu_V1/target/50.png', './baidu_V1/target/51.png',
#        './baidu_V1/target/52.png', './baidu_V1/target/53.png',
#        './baidu_V1/target/54.png', './baidu_V1/target/55.png',
#        './baidu_V1/target/56.png', './baidu_V1/target/57.png',
#        './baidu_V1/target/58.png', './baidu_V1/target/59.png',
#        './baidu_V1/target/60.png', './baidu_V1/target/61.png',
#        './baidu_V1/target/62.png', './baidu_V1/target/63.png',
#        './baidu_V1/target/64.png', './baidu_V1/target/65.png',
#        './baidu_V1/target/66.png', './baidu_V1/target/67.png',
#        './baidu_V1/target/68.png', './baidu_V1/target/69.png',
#        './baidu_V1/target/70.png', './baidu_V1/target/71.png',
#        './baidu_V1/target/72.png', './baidu_V1/target/73.png',
#        './baidu_V1/target/74.png', './baidu_V1/target/75.png',
#        './baidu_V1/target/76.png', './baidu_V1/target/77.png',
#        './baidu_V1/target/78.png', './baidu_V1/target/79.png',
#        './baidu_V1/target/80.png', './baidu_V1/target/81.png',
#        './baidu_V1/target/82.png', './baidu_V1/target/83.png',
#        './baidu_V1/target/84.png', './baidu_V1/target/85.png',
#        './baidu_V1/target/86.png', './baidu_V1/target/87.png',
#        './baidu_V1/target/88.png', './baidu_V1/target/89.png',
#        './baidu_V1/target/90.png', './baidu_V1/target/91.png',
#        './baidu_V1/target/92.png', './baidu_V1/target/93.png',
#        './baidu_V1/target/94.png', './baidu_V1/target/95.png',
#        './baidu_V1/target/96.png', './baidu_V1/target/97.png',
#        './baidu_V1/target/98.png', './baidu_V1/target/99.png',
#        './baidu_V1/target/100.png', './baidu_V1/target/101.png',
#        './baidu_V1/target/102.png', './baidu_V1/target/103.png',
#        './baidu_V1/target/104.png', './baidu_V1/target/105.png',
#        './baidu_V1/target/106.png', './baidu_V1/target/107.png',
#        './baidu_V1/target/108.png', './baidu_V1/target/109.png',
#        './baidu_V1/target/110.png', './baidu_V1/target/111.png',
#        './baidu_V1/target/112.png', './baidu_V1/target/113.png',
#        './baidu_V1/target/114.png', './baidu_V1/target/115.png',
#        './baidu_V1/target/116.png', './baidu_V1/target/117.png',
#        './baidu_V1/target/118.png', './baidu_V1/target/119.png',
#        './baidu_V1/target/120.png', './baidu_V1/target/121.png',
#        './baidu_V1/target/122.png', './baidu_V1/target/123.png',
#        './baidu_V1/target/124.png', './baidu_V1/target/125.png',
#        './baidu_V1/target/126.png', './baidu_V1/target/127.png',
#        './baidu_V1/target/128.png', './baidu_V1/target/129.png',
#        './baidu_V1/target/130.png', './baidu_V1/target/131.png',
#        './baidu_V1/target/132.png', './baidu_V1/target/133.png',
#        './baidu_V1/target/134.png', './baidu_V1/target/135.png',
#        './baidu_V1/target/136.png', './baidu_V1/target/137.png',
#        './baidu_V1/target/138.png', './baidu_V1/target/139.png',
#        './baidu_V1/target/140.png', './baidu_V1/target/141.png',
#        './baidu_V1/target/142.png', './baidu_V1/target/143.png',
#        './baidu_V1/target/144.png', './baidu_V1/target/145.png',
#        './baidu_V1/target/146.png', './baidu_V1/target/147.png',
#        './baidu_V1/target/148.png', './baidu_V1/target/149.png',
#        './baidu_V1/target/150.png', './baidu_V1/target/151.png',
#        './baidu_V1/target/153.png', './baidu_V1/target/154.png',
#        './baidu_V1/target/155.png', './baidu_V1/target/156.png',
#        './baidu_V1/target/157.png', './baidu_V1/target/158.png',
#        './baidu_V1/target/159.png', './baidu_V1/target/160.png',
#        './baidu_V1/target/161.png', './baidu_V1/target/162.png',
#        './baidu_V1/target/163.png', './baidu_V1/target/164.png',
#        './baidu_V1/target/165.png', './baidu_V1/target/166.png',
#        './baidu_V1/target/167.png', './baidu_V1/target/168.png',
#        './baidu_V1/target/169.png', './baidu_V1/target/170.png',
#        './baidu_V1/target/171.png', './baidu_V1/target/172.png',
#        './baidu_V1/target/173.png', './baidu_V1/target/174.png',
#        './baidu_V1/target/175.png', './baidu_V1/target/176.png',
#        './baidu_V1/target/177.png', './baidu_V1/target/178.png',
#        './baidu_V1/target/179.png', './baidu_V1/target/180.png',
#        './baidu_V1/target/181.png', './baidu_V1/target/182.png',
#        './baidu_V1/target/183.png', './baidu_V1/target/184.png',
#        './baidu_V1/target/185.png', './baidu_V1/target/186.png',
#        './baidu_V1/target/187.png', './baidu_V1/target/188.png',
#        './baidu_V1/target/189.png', './baidu_V1/target/190.png',
#        './baidu_V1/target/191.png', './baidu_V1/target/192.png',
#        './baidu_V1/target/193.png', './baidu_V1/target/194.png',
#        './baidu_V1/target/195.png', './baidu_V1/target/196.png',
#        './baidu_V1/target/197.png', './baidu_V1/target/198.png',
#        './baidu_V1/target/199.png', './baidu_V1/target/200.png',
#        './baidu_V1/target/201.png', './baidu_V1/target/202.png',
#        './baidu_V1/target/203.png', './baidu_V1/target/204.png',
#        './baidu_V1/target/205.png', './baidu_V1/target/206.png',
#        './baidu_V1/target/207.png', './baidu_V1/target/208.png',
#        './baidu_V1/target/209.png', './baidu_V1/target/210.png',
#        './baidu_V1/target/211.png', './baidu_V1/target/212.png',
#        './baidu_V1/target/213.png', './baidu_V1/target/214.png',
#        './baidu_V1/target/215.png', './baidu_V1/target/216.png',
#        './baidu_V1/target/217.png', './baidu_V1/target/218.png',
#        './baidu_V1/target/219.png', './baidu_V1/target/220.png',
#        './baidu_V1/target/221.png', './baidu_V1/target/222.png',
#        './baidu_V1/target/223.png', './baidu_V1/target/224.png',
#        './baidu_V1/target/225.png', './baidu_V1/target/226.png',
#        './baidu_V1/target/227.png', './baidu_V1/target/228.png',
#        './baidu_V1/target/229.png', './baidu_V1/target/230.png',
#        './baidu_V1/target/231.png', './baidu_V1/target/232.png',
#        './baidu_V1/target/233.png', './baidu_V1/target/234.png',
#        './baidu_V1/target/235.png', './baidu_V1/target/236.png',
#        './baidu_V1/target/237.png', './baidu_V1/target/238.png',
#        './baidu_V1/target/239.png', './baidu_V1/target/240.png',
#        './baidu_V1/target/241.png', './baidu_V1/target/242.png',
#        './baidu_V1/target/243.png', './baidu_V1/target/244.png',
#        './baidu_V1/target/245.png', './baidu_V1/target/246.png',
#        './baidu_V1/target/247.png', './baidu_V1/target/248.png',
#        './baidu_V1/target/249.png', './baidu_V1/target/250.png',
#        './baidu_V1/target/251.png', './baidu_V1/target/252.png',
#        './baidu_V1/target/253.png', './baidu_V1/target/254.png',
#        './baidu_V1/target/255.png', './baidu_V1/target/256.png',
#        './baidu_V1/target/257.png', './baidu_V1/target/258.png',
#        './baidu_V1/target/259.png', './baidu_V1/target/260.png',
#        './baidu_V1/target/261.png', './baidu_V1/target/262.png',
#        './baidu_V1/target/263.png', './baidu_V1/target/264.png',
#        './baidu_V1/target/265.png', './baidu_V1/target/266.png',
#        './baidu_V1/target/267.png', './baidu_V1/target/268.png',
#        './baidu_V1/target/269.png', './baidu_V1/target/270.png',
#        './baidu_V1/target/271.png', './baidu_V1/target/272.png',
#        './baidu_V1/target/273.png', './baidu_V1/target/274.png',
#        './baidu_V1/target/275.png', './baidu_V1/target/276.png',
#        './baidu_V1/target/277.png', './baidu_V1/target/278.png',
#        './baidu_V1/target/279.png', './baidu_V1/target/280.png',
#        './baidu_V1/target/281.png', './baidu_V1/target/282.png',
#        './baidu_V1/target/283.png', './baidu_V1/target/284.png',
#        './baidu_V1/target/285.png', './baidu_V1/target/286.png',
#        './baidu_V1/target/287.png', './baidu_V1/target/288.png',
#        './baidu_V1/target/289.png', './baidu_V1/target/290.png',
#        './baidu_V1/target/291.png', './baidu_V1/target/292.png',
#        './baidu_V1/target/293.png', './baidu_V1/target/294.png',
#        './baidu_V1/target/295.png', './baidu_V1/target/296.png',
#        './baidu_V1/target/297.png', './baidu_V1/target/298.png',
#        './baidu_V1/target/299.png', './baidu_V1/target/300.png',
#        './baidu_V1/target/301.png', './baidu_V1/target/302.png',
#        './baidu_V1/target/303.png', './baidu_V1/target/304.png',
#        './baidu_V1/target/305.png', './baidu_V1/target/306.png',
#        './baidu_V1/target/307.png', './baidu_V1/target/308.png',
#        './baidu_V1/target/309.png', './baidu_V1/target/310.png',
#        './baidu_V1/target/311.png', './baidu_V1/target/312.png',
#        './baidu_V1/target/313.png', './baidu_V1/target/314.png',
#        './baidu_V1/target/315.png', './baidu_V1/target/316.png',
#        './baidu_V1/target/317.png', './baidu_V1/target/318.png',
#        './baidu_V1/target/319.png', './baidu_V1/target/320.png',
#        './baidu_V1/target/321.png', './baidu_V1/target/322.png',
#        './baidu_V1/target/323.png', './baidu_V1/target/324.png',
#        './baidu_V1/target/325.png', './baidu_V1/target/326.png',
#        './baidu_V1/target/327.png', './baidu_V1/target/328.png',
#        './baidu_V1/target/329.png', './baidu_V1/target/330.png',
#        './baidu_V1/target/331.png', './baidu_V1/target/332.png',
#        './baidu_V1/target/333.png', './baidu_V1/target/334.png',
#        './baidu_V1/target/335.png', './baidu_V1/target/336.png',
#        './baidu_V1/target/337.png', './baidu_V1/target/338.png',
#        './baidu_V1/target/339.png', './baidu_V1/target/340.png',
#        './baidu_V1/target/341.png', './baidu_V1/target/342.png',
#        './baidu_V1/target/343.png', './baidu_V1/target/344.png',
#        './baidu_V1/target/345.png', './baidu_V1/target/346.png',
#        './baidu_V1/target/347.png', './baidu_V1/target/348.png',
#        './baidu_V1/target/349.png', './baidu_V1/target/350.png',
#        './baidu_V1/target/351.png', './baidu_V1/target/352.png',
#        './baidu_V1/target/353.png', './baidu_V1/target/354.png',
#        './baidu_V1/target/355.png', './baidu_V1/target/356.png',
#        './baidu_V1/target/357.png', './baidu_V1/target/358.png',
#        './baidu_V1/target/359.png', './baidu_V1/target/360.png',
#        './baidu_V1/target/361.png', './baidu_V1/target/362.png',
#        './baidu_V1/target/363.png', './baidu_V1/target/364.png',
#        './baidu_V1/target/365.png', './baidu_V1/target/366.png',
#        './baidu_V1/target/367.png', './baidu_V1/target/368.png',
#        './baidu_V1/target/369.png', './baidu_V1/target/370.png',
#        './baidu_V1/target/371.png', './baidu_V1/target/372.png',
#        './baidu_V1/target/373.png', './baidu_V1/target/374.png',
#        './baidu_V1/target/375.png', './baidu_V1/target/376.png',
#        './baidu_V1/target/377.png', './baidu_V1/target/378.png',
#        './baidu_V1/target/379.png', './baidu_V1/target/380.png',
#        './baidu_V1/target/381.png', './baidu_V1/target/382.png',
#        './baidu_V1/target/383.png', './baidu_V1/target/384.png',
#        './baidu_V1/target/385.png', './baidu_V1/target/386.png',
#        './baidu_V1/target/387.png', './baidu_V1/target/388.png',
#        './baidu_V1/target/389.png', './baidu_V1/target/390.png',
#        './baidu_V1/target/391.png', './baidu_V1/target/392.png',
#        './baidu_V1/target/393.png', './baidu_V1/target/394.png',
#        './baidu_V1/target/395.png', './baidu_V1/target/396.png',
#        './baidu_V1/target/397.png', './baidu_V1/target/398.png',
#        './baidu_V1/target/399.png', './baidu_V1/target/400.png',
#        './baidu_V1/target/401.png', './baidu_V1/target/402.png',
#        './baidu_V1/target/403.png', './baidu_V1/target/404.png',
#        './baidu_V1/target/405.png', './baidu_V1/target/406.png',
#        './baidu_V1/target/407.png', './baidu_V1/target/408.png',
#        './baidu_V1/target/409.png', './baidu_V1/target/410.png',
#        './baidu_V1/target/411.png', './baidu_V1/target/412.png',
#        './baidu_V1/target/413.png', './baidu_V1/target/414.png',
#        './baidu_V1/target/415.png', './baidu_V1/target/416.png',
#        './baidu_V1/target/417.png', './baidu_V1/target/418.png',
#        './baidu_V1/target/419.png', './baidu_V1/target/420.png',
#        './baidu_V1/target/421.png', './baidu_V1/target/422.png',
#        './baidu_V1/target/423.png', './baidu_V1/target/424.png',
#        './baidu_V1/target/425.png', './baidu_V1/target/426.png',
#        './baidu_V1/target/427.png', './baidu_V1/target/428.png',
#        './baidu_V1/target/429.png', './baidu_V1/target/430.png',
#        './baidu_V1/target/431.png', './baidu_V1/target/432.png',
#        './baidu_V1/target/433.png', './baidu_V1/target/434.png',
#        './baidu_V1/target/435.png', './baidu_V1/target/436.png',
#        './baidu_V1/target/437.png', './baidu_V1/target/438.png',
#        './baidu_V1/target/439.png', './baidu_V1/target/440.png',
#        './baidu_V1/target/441.png', './baidu_V1/target/442.png',
#        './baidu_V1/target/443.png', './baidu_V1/target/444.png',
#        './baidu_V1/target/445.png', './baidu_V1/target/446.png',
#        './baidu_V1/target/447.png', './baidu_V1/target/448.png',
#        './baidu_V1/target/449.png', './baidu_V1/target/450.png',
#        './baidu_V1/target/451.png', './baidu_V1/target/452.png',
#        './baidu_V1/target/453.png', './baidu_V1/target/454.png',
#        './baidu_V1/target/455.png', './baidu_V1/target/456.png',
#        './baidu_V1/target/457.png', './baidu_V1/target/458.png',
#        './baidu_V1/target/459.png', './baidu_V1/target/460.png',
#        './baidu_V1/target/461.png', './baidu_V1/target/462.png',
#        './baidu_V1/target/463.png', './baidu_V1/target/464.png',
#        './baidu_V1/target/465.png', './baidu_V1/target/466.png',
#        './baidu_V1/target/467.png', './baidu_V1/target/468.png',
#        './baidu_V1/target/469.png', './baidu_V1/target/470.png',
#        './baidu_V1/target/471.png', './baidu_V1/target/472.png',
#        './baidu_V1/target/473.png', './baidu_V1/target/474.png',
#        './baidu_V1/target/475.png', './baidu_V1/target/476.png',
#        './baidu_V1/target/477.png', './baidu_V1/target/478.png',
#        './baidu_V1/target/479.png', './baidu_V1/target/480.png',
#        './baidu_V1/target/481.png', './baidu_V1/target/482.png',
#        './baidu_V1/target/483.png', './baidu_V1/target/484.png',
#        './baidu_V1/target/485.png', './baidu_V1/target/486.png',
#        './baidu_V1/target/487.png', './baidu_V1/target/488.png',
#        './baidu_V1/target/489.png', './baidu_V1/target/490.png',
#        './baidu_V1/target/491.png', './baidu_V1/target/492.png',
#        './baidu_V1/target/493.png', './baidu_V1/target/494.png',
#        './baidu_V1/target/495.png', './baidu_V1/target/496.png',
#        './baidu_V1/target/497.png', './baidu_V1/target/498.png',
#        './baidu_V1/target/499.png', './baidu_V1/target/500.png',
#        './baidu_V2/target/02137.jpg', './baidu_V2/target/24084.jpg',
#        './baidu_V2/target/19463.jpg', './baidu_V2/target/26693.jpg',
#        './baidu_V2/target/08208.jpg', './baidu_V2/target/09116.jpg',
#        './baidu_V2/target/06225.jpg', './baidu_V2/target/11995.jpg',
#        './baidu_V2/target/06557.jpg', './baidu_V2/target/14153.jpg',
#        './baidu_V2/target/01210.jpg', './baidu_V2/target/28682.jpg',
#        './baidu_V2/target/18741.jpg', './baidu_V2/target/02719.jpg',
#        './baidu_V2/target/24906.jpg', './baidu_V2/target/15503.jpg',
#        './baidu_V2/target/19339.jpg', './baidu_V2/target/17300.jpg',
#        './baidu_V2/target/08220.jpg', './baidu_V2/target/11771.jpg',
#        './baidu_V2/target/05704.jpg', './baidu_V2/target/16778.jpg',
#        './baidu_V2/target/01204.jpg', './baidu_V2/target/29588.jpg',
#        './baidu_V2/target/11017.jpg', './baidu_V2/target/09658.jpg',
#        './baidu_V2/target/10309.jpg', './baidu_V2/target/18966.jpg',
#        './baidu_V2/target/29563.jpg', './baidu_V2/target/24047.jpg',
#        './baidu_V2/target/05937.jpg', './baidu_V2/target/27228.jpg',
#        './baidu_V2/target/10484.jpg', './baidu_V2/target/21881.jpg',
#        './baidu_V2/target/11956.jpg', './baidu_V2/target/21895.jpg',
#        './baidu_V2/target/12287.jpg', './baidu_V2/target/04383.jpg',
#        './baidu_V2/target/17499.jpg', './baidu_V2/target/23072.jpg',
#        './baidu_V2/target/25417.jpg', './baidu_V2/target/00867.jpg',
#        './baidu_V2/target/27200.jpg', './baidu_V2/target/21117.jpg',
#        './baidu_V2/target/14423.jpg', './baidu_V2/target/04630.jpg',
#        './baidu_V2/target/02241.jpg', './baidu_V2/target/22191.jpg',
#        './baidu_V2/target/01990.jpg', './baidu_V2/target/00456.jpg',
#        './baidu_V2/target/02527.jpg', './baidu_V2/target/04156.jpg',
#        './baidu_V2/target/03639.jpg', './baidu_V2/target/02533.jpg',
#        './baidu_V2/target/26485.jpg', './baidu_V2/target/06033.jpg',
#        './baidu_V2/target/09300.jpg', './baidu_V2/target/00442.jpg',
#        './baidu_V2/target/16208.jpg', './baidu_V2/target/08750.jpg',
#        './baidu_V2/target/07463.jpg', './baidu_V2/target/28480.jpg',
#        './baidu_V2/target/17664.jpg', './baidu_V2/target/28494.jpg',
#        './baidu_V2/target/04618.jpg', './baidu_V2/target/10686.jpg',
#        './baidu_V2/target/26334.jpg', './baidu_V2/target/14386.jpg',
#        './baidu_V2/target/22634.jpg', './baidu_V2/target/29775.jpg',
#        './baidu_V2/target/17843.jpg', './baidu_V2/target/26446.jpg',
#        './baidu_V2/target/16585.jpg', './baidu_V2/target/25629.jpg',
#        './baidu_V2/target/23258.jpg', './baidu_V2/target/15932.jpg',
#        './baidu_V2/target/29013.jpg', './baidu_V2/target/20989.jpg',
#        './baidu_V2/target/25601.jpg', './baidu_V2/target/21467.jpg',
#        './baidu_V2/target/21301.jpg', './baidu_V2/target/08793.jpg',
#        './baidu_V2/target/25173.jpg', './baidu_V2/target/21315.jpg',
#        './baidu_V2/target/06972.jpg', './baidu_V2/target/21473.jpg',
#        './baidu_V2/target/04803.jpg', './baidu_V2/target/15649.jpg',
#        './baidu_V2/target/13238.jpg', './baidu_V2/target/15891.jpg',
#        './baidu_V2/target/04744.jpg', './baidu_V2/target/14557.jpg',
#        './baidu_V2/target/09260.jpg', './baidu_V2/target/05328.jpg',
#        './baidu_V2/target/27837.jpg', './baidu_V2/target/19067.jpg',
#        './baidu_V2/target/02321.jpg', './baidu_V2/target/04988.jpg',
#        './baidu_V2/target/20816.jpg', './baidu_V2/target/02309.jpg'],
#       dtype='<U27')

# %%
val_datagen.show_sample_image()

# %%
# imutils.resize?

# %% [markdown]
# ## Training Model

# %%
from keras.optimizers import Adam
import keras.backend as K
import tensorflow as tf
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
class SINetLoss:
    def __init__(self, lamda=0.9):
        self.lamda = lamda

    def gt_dilation(self, y_true):
        y_true = tf.reshape(y_true, (-1, IMG_HEIGHT, IMG_WIDTH, N_CLASSES))
        dilation = tf.nn.max_pool2d(y_true, ksize=(15, 15), strides=1, name='dilation2D', padding="SAME")
        dilation = tf.reshape(dilation, (-1, IMG_HEIGHT*IMG_WIDTH, N_CLASSES))

        return dilation

    def gt_erosion(self, y_true):
        y_true = tf.reshape(y_true, (-1, IMG_HEIGHT, IMG_WIDTH, N_CLASSES))
        erosion = -tf.nn.max_pool2d(-y_true, ksize=(15, 15), strides=1, name='erosion2D', padding="SAME")
        erosion = tf.reshape(erosion, (-1, IMG_HEIGHT*IMG_WIDTH, N_CLASSES))

        return erosion

    def log_loss(self, y_true, y_pred):
        loss = -tf.reduce_sum(y_true * tf.math.log(y_pred), axis=-1)
        return loss

    def boundary_loss(self, y_true, y_pred):
        dilation = self.gt_dilation(y_true)
        erosion = self.gt_erosion(y_true)

        boundary = tf.math.subtract(dilation, erosion)
#         boundary = tf.reshape(boundary, (-1, IMG_HEIGHT*IMG_WIDTH, N_CLASSES))
#         assign_indices = tf.count_nonzero(boundary, axis=-1)
#         assign_indices = tf.where(boundary)
#         print(tf.shape(boundary).eval(session=tf.compat.v1.Session()))
#         mask = tf.math.greater(tf.to_float(boundary), tf.constant(0.0))
#         zeros_mask = tf.zeros_like(boundary)

#         b_true = tf.where(mask, y_true, zeros_mask)
#         b_pred = tf.where(mask, y_pred, zeros_mask)
        loss = -tf.reduce_sum(boundary * tf.math.log(y_pred), axis=-1)

        return loss

    def compute_loss(self, y_true, y_pred):
        batch_size = tf.shape(y_pred)[0]
        self.lamda = self.lamda
        log_loss_ = tf.cast(self.log_loss(y_true, y_pred), tf.float32)
        boundary_loss_ = tf.cast(self.boundary_loss(y_true, y_pred), tf.float32)
        total_loss = log_loss_ + self.lamda * boundary_loss_
#         total_loss = tf.cast(total_loss, tf.float32)
        total_loss *= tf.cast(batch_size, tf.float32)

        return total_loss

# %%
# tf.nn.dilation2d?
sinet_loss = SINetLoss().compute_loss

# %%
init_lr = 7.5e-3

opt = tf.keras.optimizers.legacy.Adam(lr=init_lr, decay=2e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-07)
model.compile(optimizer=opt, loss=sinet_loss, metrics=["accuracy"])

# %%
trained_weight = "/content/drive/MyDrive/Colab Notebooks/trained_weight"

if not os.path.exists(trained_weight):
    os.mkdir(trained_weight)

# %%
import keras.backend as K
import keras.callbacks as cbks

# %%
class CustomMetrics(cbks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        for k in logs:
            if k.endswith('boundary_loss'):
                print(logs[k])

# %%
checkpoints = ModelCheckpoint(filepath=os.path.join(trained_weight, "best_weights.h5"),
                              monitor="val_loss",
                              save_weights_only=True,
                              save_best_only=True,
                              verbose=1)

# %%
cd trained_weight
# Out:
# /content/drive/MyDrive/Colab Notebooks/trained_weight

# %%
# !ls
# Out:
# best_weights_1_all.h5  best_weights_2.h5  best_weights_4_all.h5  best_weights_all.h5
# best_weights_2_all.h5  best_weights_3.h5  best_weights_4.h5	 best_weights.h5

# %%
checkpoints = ModelCheckpoint(filepath=os.path.join(trained_weight, "best_weights_4_all.h5"),
                              monitor="val_loss",
                              save_weights_only=True,
                              save_best_only=True,
                              verbose=1)

# %%
for idx, layer in enumerate(model.layers):
    print(idx, layer.name, layer.trainable)

    layer.trainable = True
    if idx > 361:
        layer.trainable = False
# Out:
# 0 input_1 True
# 1 swap_color_channel True
# 2 mean_substraction_inputs True
# 3 conv_1_pad True
# 4 conv_1 True
# 5 conv_1_bn True
# 6 conv_1_act True
# 7 conv_pad_2 True
# 8 conv_dw_2 True
# 9 conv_dw_2_bn True
# 10 conv_dw_2_Prelu True
# 11 conv_pw_2 True
# 12 conv_pw_2_bn True
# 13 conv_pw_2_relu True
# 14 squeeze_glo_avg_2 True
# 15 squeeze_squ_2 True
# 16 squeeze_exci_2 True
# 17 squeeze_scale_2 True
# 18 activation True
# 19 conv_pad_3 True
# 20 conv_dw_3 True
# 21 conv_dw_3_bn True
# 22 conv_dw_3_Prelu True
# 23 conv_pw_3 True
# 24 conv_pw_3_bn True
# 25 conv_pw_3_relu True
# 26 squeeze_glo_avg_3 True
# 27 squeeze_squ_3 True
# 28 squeeze_exci_3 True
# 29 squeeze_scale_3 True
# 30 activation_1 True
# 31 conv_4 True
# 32 conv_4_bn True
# 33 conv_4_act True
# 34 average_pooling2d True
# 35 average_pooling2d_1 True
# 36 activation_2 True
# 37 activation_4 True
# 38 conv_pad_4_1 True
# 39 conv_pad_4_2 True
# 40 conv_dw_4_1 True
# 41 conv_dw_4_2 True
# 42 conv_dw_4_1_bn True
# 43 conv_dw_4_2_bn True
# 44 conv_dw_4_1_Prelu True
# 45 conv_dw_4_2_Prelu True
# 46 conv_pw_4_1 True
# 47 conv_pw_4_2 True
# 48 conv_pw_4_1_bn True
# 49 conv_pw_4_2_bn True
# 50 conv_pw_4_1_relu True
# 51 conv_pw_4_2_relu True
# 52 s2_block_4_1 True
# 53 s2_block_4_2 True
# 54 batch_normalization True
# 55 batch_normalization_1 True
# 56 activation_3 True
# 57 activation_5 True
# 58 concatenate True
# 59 add True
# 60 p_re_lu True
# 61 conv_5 True
# 62 conv_5_bn True
# 63 conv_5_act True
# 64 average_pooling2d_2 True
# 65 average_pooling2d_3 True
# 66 activation_6 True
# 67 activation_8 True
# 68 conv_pad_5_1 True
# 69 conv_pad_5_2 True
# 70 conv_dw_5_1 True
# 71 conv_dw_5_2 True
# 72 conv_dw_5_1_bn True
# 73 conv_dw_5_2_bn True
# 74 conv_dw_5_1_Prelu True
# 75 conv_dw_5_2_Prelu True
# 76 conv_pw_5_1 True
# 77 conv_pw_5_2 True
# 78 conv_pw_5_1_bn True
# 79 conv_pw_5_2_bn True
# 80 conv_pw_5_1_relu True
# 81 conv_pw_5_2_relu True
# 82 s2_block_5_1 True
# 83 s2_block_5_2 True
# 84 batch_normalization_2 True
# 85 batch_normalization_3 True
# 86 activation_7 True
# 87 activation_9 True
# 88 concatenate_1 True
# 89 add_1 True
# 90 p_re_lu_1 True
# 91 concat_2_5 True
# 92 conv_pad_6 True
# 93 conv_dw_6 True
# 94 conv_dw_6_bn True
# 95 conv_dw_6_Prelu True
# 96 conv_pw_6 True
# 97 conv_pw_6_bn True
# 98 conv_pw_6_relu True
# 99 squeeze_glo_avg_6 True
# 100 squeeze_squ_6 True
# 101 squeeze_exci_6 True
# 102 squeeze_scale_6 True
# 103 activation_10 True
# 104 conv_pad_7 True
# 105 conv_dw_7 True
# 106 conv_dw_7_bn True
# 107 conv_dw_7_Prelu True
# 108 conv_pw_7 True
# 109 conv_pw_7_bn True
# 110 conv_pw_7_relu True
# 111 squeeze_glo_avg_7 True
# 112 squeeze_squ_7 True
# 113 squeeze_exci_7 True
# 114 squeeze_scale_7 True
# 115 activation_11 True
# 116 conv_8 True
# 117 conv_8_bn True
# 118 conv_8_act True
# 119 average_pooling2d_4 True
# 120 average_pooling2d_5 True
# 121 activation_12 True
# 122 activation_14 True
# 123 conv_pad_8_1 True
# 124 conv_pad_8_2 True
# 125 conv_dw_8_1 True
# 126 conv_dw_8_2 True
# 127 conv_dw_8_1_bn True
# 128 conv_dw_8_2_bn True
# 129 conv_dw_8_1_Prelu True
# 130 conv_dw_8_2_Prelu True
# 131 conv_pw_8_1 True
# 132 conv_pw_8_2 True
# 133 conv_pw_8_1_bn True
# 134 conv_pw_8_2_bn True
# 135 conv_pw_8_1_relu True
# 136 conv_pw_8_2_relu True
# 137 s2_block_8_1 True
# 138 s2_block_8_2 True
# 139 batch_normalization_4 True
# 140 batch_normalization_5 True
# 141 activation_13 True
# 142 activation_15 True
# 143 concatenate_2 True
# 144 add_2 True
# 145 p_re_lu_2 True
# 146 conv_9 True
# 147 conv_9_bn True
# 148 conv_9_act True
# 149 average_pooling2d_6 True
# 150 average_pooling2d_7 True
# 151 activation_16 True
# 152 activation_18 True
# 153 conv_pad_9_1 True
# 154 conv_pad_9_2 True
# 155 conv_dw_9_1 True
# 156 conv_dw_9_2 True
# 157 conv_dw_9_1_bn True
# 158 conv_dw_9_2_bn True
# 159 conv_dw_9_1_Prelu True
# 160 conv_dw_9_2_Prelu True
# 161 conv_pw_9_1 True
# 162 conv_pw_9_2 True
# 163 conv_pw_9_1_bn True
# 164 conv_pw_9_2_bn True
# 165 conv_pw_9_1_relu True
# 166 conv_pw_9_2_relu True
# 167 s2_block_9_1 True
# 168 s2_block_9_2 True
# 169 batch_normalization_6 True
# 170 batch_normalization_7 True
# 171 activation_17 True
# 172 activation_19 True
# 173 concatenate_3 True
# 174 add_3 True
# 175 p_re_lu_3 True
# 176 conv_10 True
# 177 conv_10_bn True
# 178 conv_10_act True
# 179 average_pooling2d_8 True
# 180 average_pooling2d_9 True
# 181 activation_20 True
# 182 activation_22 True
# 183 conv_pad_10_1 True
# 184 conv_pad_10_2 True
# 185 conv_dw_10_1 True
# 186 conv_dw_10_2 True
# 187 conv_dw_10_1_bn True
# 188 conv_dw_10_2_bn True
# 189 conv_dw_10_1_Prelu True
# 190 conv_dw_10_2_Prelu True
# 191 conv_pw_10_1 True
# 192 conv_pw_10_2 True
# 193 conv_pw_10_1_bn True
# 194 conv_pw_10_2_bn True
# 195 conv_pw_10_1_relu True
# 196 conv_pw_10_2_relu True
# 197 s2_block_10_1 True
# 198 s2_block_10_2 True
# 199 batch_normalization_8 True
# 200 batch_normalization_9 True
# 201 activation_21 True
# 202 activation_23 True
# 203 concatenate_4 True
# 204 add_4 True
# 205 p_re_lu_4 True
# 206 conv_11 True
# 207 conv_11_bn True
# 208 conv_11_act True
# 209 average_pooling2d_10 True
# 210 average_pooling2d_11 True
# 211 activation_24 True
# 212 activation_26 True
# 213 conv_pad_11_1 True
# 214 conv_pad_11_2 True
# 215 conv_dw_11_1 True
# 216 conv_dw_11_2 True
# 217 conv_dw_11_1_bn True
# 218 conv_dw_11_2_bn True
# 219 conv_dw_11_1_Prelu True
# 220 conv_dw_11_2_Prelu True
# 221 conv_pw_11_1 True
# 222 conv_pw_11_2 True
# 223 conv_pw_11_1_bn True
# 224 conv_pw_11_2_bn True
# 225 conv_pw_11_1_relu True
# 226 conv_pw_11_2_relu True
# 227 s2_block_11_1 True
# 228 s2_block_11_2 True
# 229 batch_normalization_10 True
# 230 batch_normalization_11 True
# 231 activation_25 True
# 232 activation_27 True
# 233 concatenate_5 True
# 234 add_5 True
# 235 p_re_lu_5 True
# 236 conv_12 True
# 237 conv_12_bn True
# 238 conv_12_act True
# 239 average_pooling2d_12 True
# 240 average_pooling2d_13 True
# 241 activation_28 True
# 242 activation_30 True
# 243 conv_pad_12_1 True
# 244 conv_pad_12_2 True
# 245 conv_dw_12_1 True
# 246 conv_dw_12_2 True
# 247 conv_dw_12_1_bn True
# 248 conv_dw_12_2_bn True
# 249 conv_dw_12_1_Prelu True
# 250 conv_dw_12_2_Prelu True
# 251 conv_pw_12_1 True
# 252 conv_pw_12_2 True
# 253 conv_pw_12_1_bn True
# 254 conv_pw_12_2_bn True
# 255 conv_pw_12_1_relu True
# 256 conv_pw_12_2_relu True
# 257 s2_block_12_1 True
# 258 s2_block_12_2 True
# 259 batch_normalization_12 True
# 260 batch_normalization_13 True
# 261 activation_29 True
# 262 activation_31 True
# 263 concatenate_6 True
# 264 add_6 True
# 265 p_re_lu_6 True
# 266 conv_13 True
# 267 conv_13_bn True
# 268 conv_13_act True
# 269 average_pooling2d_14 True
# 270 average_pooling2d_15 True
# 271 activation_32 True
# 272 activation_34 True
# 273 conv_pad_13_1 True
# 274 conv_pad_13_2 True
# 275 conv_dw_13_1 True
# 276 conv_dw_13_2 True
# 277 conv_dw_13_1_bn True
# 278 conv_dw_13_2_bn True
# 279 conv_dw_13_1_Prelu True
# 280 conv_dw_13_2_Prelu True
# 281 conv_pw_13_1 True
# 282 conv_pw_13_2 True
# 283 conv_pw_13_1_bn True
# 284 conv_pw_13_2_bn True
# 285 conv_pw_13_1_relu True
# 286 conv_pw_13_2_relu True
# 287 s2_block_13_1 True
# 288 s2_block_13_2 True
# 289 batch_normalization_14 True
# 290 batch_normalization_15 True
# 291 activation_33 True
# 292 activation_35 True
# 293 concatenate_7 True
# 294 add_7 True
# 295 p_re_lu_7 True
# 296 conv_14 True
# 297 conv_14_bn True
# 298 conv_14_act True
# 299 average_pooling2d_16 True
# 300 average_pooling2d_17 True
# 301 activation_36 True
# 302 activation_38 True
# 303 conv_pad_14_1 True
# 304 conv_pad_14_2 True
# 305 conv_dw_14_1 True
# 306 conv_dw_14_2 True
# 307 conv_dw_14_1_bn True
# 308 conv_dw_14_2_bn True
# 309 conv_dw_14_1_Prelu True
# 310 conv_dw_14_2_Prelu True
# 311 conv_pw_14_1 True
# 312 conv_pw_14_2 True
# 313 conv_pw_14_1_bn True
# 314 conv_pw_14_2_bn True
# 315 conv_pw_14_1_relu True
# 316 conv_pw_14_2_relu True
# 317 s2_block_14_1 True
# 318 s2_block_14_2 True
# 319 batch_normalization_16 True
# 320 batch_normalization_17 True
# 321 activation_37 True
# 322 activation_39 True
# 323 concatenate_8 True
# 324 add_8 True
# 325 p_re_lu_8 True
# 326 conv_15 True
# 327 conv_15_bn True
# 328 conv_15_act True
# 329 average_pooling2d_18 True
# 330 average_pooling2d_19 True
# 331 activation_40 True
# 332 activation_42 True
# 333 conv_pad_15_1 True
# 334 conv_pad_15_2 True
# 335 conv_dw_15_1 True
# 336 conv_dw_15_2 True
# 337 conv_dw_15_1_bn True
# 338 conv_dw_15_2_bn True
# 339 conv_dw_15_1_Prelu True
# 340 conv_dw_15_2_Prelu True
# 341 conv_pw_15_1 True
# 342 conv_pw_15_2 True
# 343 conv_pw_15_1_bn True
# 344 conv_pw_15_2_bn True
# 345 conv_pw_15_1_relu True
# 346 conv_pw_15_2_relu True
# 347 s2_block_15_1 True
# 348 s2_block_15_2 True
# 349 batch_normalization_18 True
# 350 batch_normalization_19 True
# 351 activation_41 True
# 352 activation_43 True
# 353 concatenate_9 True
# 354 add_9 True
# 355 p_re_lu_9 True
# 356 concat_16_7 True
# 357 activation_44 True
# 358 conv_pw_16 True
# 359 conv_pw_16_bn True
# 360 conv_pw_16_relu True
# 361 activation_45 True
# 362 up_sampling2d False
# 363 batch_normalization_20 False
# 364 conv_pw_18 False
# 365 activation_46 False
# 366 conv_pw_18_bn False
# 367 tf.math.reduce_max False
# 368 conv_pw_18_relu False
# 369 information_blocking_decoder False
# 370 multiply False
# 371 activation_47 False
# 372 add_10 False
# 373 activation_48 False
# 374 up_sampling2d_1 False
# 375 batch_normalization_21 False
# 376 activation_49 False
# 377 conv_19 False
# 378 conv_19_bn False
# 379 conv_19_act False
# 380 up_sampling2d_2 False
# 381 batch_normalization_22 False
# 382 activation_50 False
# 383 reshape False
# 384 activation_51 False

# %%
H = model.fit_generator(train_datagen.generate(),
                        epochs=300,
                        steps_per_epoch=train_datagen.get_n_examples() // train_datagen.batch_size,
                        validation_data=val_datagen.generate(),
                        validation_steps=val_datagen.get_n_examples() // val_datagen.batch_size,
                        callbacks=[checkpoints],
                        initial_epoch=0
                        )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-109-2974068c0ae6> in <cell line: 1>()
# ----> 1 H = model.fit_generator(train_datagen.generate(),
#       2                         epochs=300,
#       3                         steps_per_epoch=train_datagen.get_n_examples() // train_datagen.batch_size,
#       4                         validation_data=val_datagen.generate(),
#       5                         validation_steps=val_datagen.get_n_examples() // val_datagen.batch_size,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2887             stacklevel=2,
#    2888         )
# -> 2889         return self.fit(
#    2890             generator,
#    2891             steps_per_epoch=steps_per_epoch,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# <ipython-input-81-58975d0f6d83> in generate(self)
#     192     def generate(self):
#     193         while True:
# --> 194             images, labels = self.load_batch()
#     195
#     196             yield (images, labels)
#
# <ipython-input-81-58975d0f6d83> in load_batch(self)
#     186         seg_batch_paths = self.label_paths[self.current_index:self.current_index+self.batch_size]
#     187         self.current_index += self.batch_size
# --> 188         inputs, segs = self.load_batch_pair_in_pair(img_batch_paths, seg_batch_paths)
#     189
#     190         return inputs, segs
#
# <ipython-input-81-58975d0f6d83> in load_batch_pair_in_pair(self, img_paths, label_paths)
#      84 #             seg = self.parse_label(seg)
#      85 #             seg = np.argmax(seg, axis=-1).astype(np.int32)
# ---> 86             segmap = SegmentationMapsOnImage(seg, shape=image.shape)
#      87
#      88             if self.augmentation:
#
# AttributeError: 'NoneType' object has no attribute 'shape'
